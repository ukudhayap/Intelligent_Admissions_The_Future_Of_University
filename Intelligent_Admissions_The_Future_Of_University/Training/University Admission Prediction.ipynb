# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"/content/adm_data.csv")

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='University Rating',data=df)
plt.xlabel('University Rating')
plt.title('Distribution of University rating')
plt.show()

# %%
plt.title("Distribution of University Rating")
df['University Rating'].value_counts().plot.pie(autopct='%1.1f%%',figsize=(10,7)) 
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='Research',data=df,palette='Set1')
plt.title('Distribution of People who have written Research Papers')
plt.xlabel('Research Papers')
plt.show()

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# 25%      3.000000    8.170000    0.000000          0.640000
# 50%      3.500000    8.610000    1.000000          0.730000
# 75%      4.000000    9.062500    1.000000          0.830000
# max      5.000000    9.920000    1.000000          0.970000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
df['Research'] = df['Research'].astype(str).apply(lambda x: x.replace('.0',''))
df['University Rating'] =  df['University Rating'].astype(str).apply(lambda x: x.replace('.0',''))

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score         SOP        LOR   \
# count  400.000000  400.000000   400.000000  400.000000  400.000000
# mean   200.500000  316.807500   107.410000    3.400000    3.452500
# std    115.614301   11.473646     6.069514    1.006869    0.898478
# min      1.000000  290.000000    92.000000    1.000000    1.000000
# 25%    100.750000  308.000000   103.000000    2.500000    3.000000
# 50%    200.500000  317.000000   107.000000    3.500000    3.500000
# 75%    300.250000  325.000000   112.000000    4.000000    4.000000
# max    400.000000  340.000000   120.000000    5.000000    5.000000
#
#              CGPA  Chance of Admit
# count  400.000000        400.000000
# mean     8.598925          0.724350
# std      0.596317          0.142609
# min      6.800000          0.340000
# 25%      8.170000          0.640000
# 50%      8.610000          0.730000
# 75%      9.062500          0.830000
# max      9.920000          0.970000

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                 4  4.5   4.5  9.65
# 1           2        324          107                 4  4.0   4.5  8.87
# 2           3        316          104                 3  3.0   3.5  8.00
# 3           4        322          110                 3  3.5   2.5  8.67
# 4           5        314          103                 2  2.0   3.0  8.21
#
#   Research  Chance of Admit
# 0        1              0.92
# 1        1              0.76
# 2        1              0.72
# 3        1              0.80
# 4        0              0.65

# %%
df.drop(df.columns[[0, 4]], axis = 1, inplace = True)

# %%
df.sort_values(by=['CGPA'], inplace=True,ascending=False)
df
# Out:
#      GRE Score  TOEFL Score University Rating  LOR   CGPA Research  \
# 143        340          120                 4   4.0  9.92        1
# 202        340          120                 5   4.5  9.91        1
# 203        334          120                 5   5.0  9.87        1
# 385        335          117                 5   5.0  9.82        1
# 34         331          112                 5   5.0  9.80        1
# ..         ...          ...               ...   ...   ...      ...
# 29         310           99                 2   2.0  7.30        0
# 118        296           99                 2   3.5  7.28        0
# 348        302           99                 1   2.0  7.25        0
# 28         295           93                 1   2.0  7.20        0
# 58         300           99                 1   2.0  6.80        1
#
#      Chance of Admit
# 143              0.97
# 202              0.97
# 203              0.97
# 385              0.96
# 34               0.94
# ..                ...
# 29               0.54
# 118              0.47
# 348              0.57
# 28               0.46
# 58               0.36
#
# [400 rows x 7 columns]

# %%
df.sample(5)
# Out:
#      GRE Score  TOEFL Score University Rating  LOR   CGPA Research  \
# 146        315          105                 3   2.5  8.48        0
# 363        306          103                 2   3.0  8.36        0
# 195        307          107                 2   3.5  8.52        1
# 82         320          110                 5   4.5  9.22        1
# 232        312          107                 2   3.5  8.27        0
#
#      Chance of Admit
# 146              0.75
# 363              0.69
# 195              0.78
# 82               0.92
# 232              0.69

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1:]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import random
from sklearn import metrics

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=0,test_size=0.2)

# %%
X_train.head()
# Out:
#      GRE Score  TOEFL Score University Rating  LOR   CGPA Research
# 40         308          110                 3   3.0  8.00        1
# 35         320          110                 5   5.0  9.20        1
# 98         332          119                 4   4.5  9.24        1
# 395        324          110                 3   3.5  9.04        1
# 353        300          102                 3   2.5  8.17        0

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
X_test
# Out:
#      GRE Score  TOEFL Score University Rating  LOR   CGPA Research
# 1          324          107                 4   4.5  8.87        1
# 331        311          105                 2   2.0  8.12        1
# 13         307          109                 3   3.0  8.00        1
# 145        320          113                 2   2.5  8.64        1
# 219        312          104                 3   3.5  8.42        0
# ..         ...          ...               ...   ...   ...      ...
# 212        338          120                 4   5.0  9.66        1
# 95         304          100                 4   2.5  7.84        0
# 241        317          103                 2   2.0  8.15        0
# 160        315          103                 1   2.0  7.86        0
# 207        310          102                 3   4.0  8.02        1
#
# [80 rows x 6 columns]

# %%
y_test.head()
# Out:
#      Chance of Admit
# 1                0.76
# 331              0.73
# 13               0.62
# 145              0.81
# 219              0.74

# %%
from sklearn.metrics import r2_score

# %%
print("Accuracy of the model is",r2_score(y_test,y_pred))
# Out:
# Accuracy of the model is 0.8094433485673075

# %%
user_input = [[333,118,5,5.0,9.04,1]]
user_pred = lr.predict(user_input)
print((user_pred.flatten()*100).astype(float))
# Out:
# [89.21905168]
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
pickle.dump(lr,open('model1.pkl','wb'))
